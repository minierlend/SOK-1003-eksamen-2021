# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def kredit():
    laanemengde = input('Hvor mye vil du låne? \n')
    laanemengde = float(laanemengde.replace(' ', ''))

    maaneder = input('Hvor mange måneder vil du ha lånet? \n')
    maaneder = int(maaneder)


    rente = input('Hva er renten på lånet ditt? \n')
    rente = float(rente.replace(',', '.').replace('%', ''))

    periodegebyr = input('Hvor mye er periodegebyret på? ? \n')
    periodegebyr = float(periodegebyr)

    laan = laanemengde * ( 1 + rente/100 ) + periodegebyr * maaneder
    
    x_akse = np.linspace(0, maaneder, int(laan))
    y_akse = laanemengde * (1 + rente/100)  **  x_akse + periodegebyr * maaneder
    fig = plt.figure(figsize=(10,5))
    plt.plot(x_akse, y_akse)
    plt.xlabel('Måneder')
    plt.ylabel('Lån')
    plt.ticklabel_format(useOffset=False, style='plain')
    
    plt.show()

    print("Din endelige sum blir \n (%.2f) " % laan)

# %%
def annunitets():
    lanemengde = input('Hvor mye vil du låne? \n')
    lanemengde = float(lanemengde.replace(' ', ''))

    terminer = float(input('Hvor mange år vil du ha lånet? \n')) * 12

    rente = float(input('Hva er renten på lånet ditt? \n').replace(',', '.').replace('%', '')) / 100 / 12

    terminbelop = lanemengde * (rente * (1 + rente) ** terminer) / ((1 + rente) ** terminer - 1)


    tabell = []

    termin = 1


    while lanemengde > 0:
        m_rente = rente * lanemengde
        avdrag = terminbelop - m_rente
        lanemengde = lanemengde - avdrag
        tabell.append([termin, terminbelop, m_rente, avdrag, lanemengde])
        termin += 1

    inn = 1
 


    df = pd.DataFrame(tabell, columns=['Termin', 'Terminbeløp', 'Renter', 'Avdrag', 'Restgjeld']).astype(int)
    while (inn != 0 ):
        print(df.truncate(before=inn - 1, after=inn + 3).to_string(index=False))
        inn = int(input('\nHvilken termin vil du se? (0 for å avslutte)\n: '))

# %%
def egenandel():
    kapital = input('Hvor mye koster huset du ønsker å kjøpe?\n')
    kapital = float(kapital.replace(' ', ''))
                            
    egenkapital = kapital * 0.15



    plt.pie([kapital-egenkapital, egenkapital], labels=["kapital", "egenandel"],  explode=(0.05, 0.05))
    plt.title('Husets verdi')
    plt.show()

    print("Egenkapitalen som trengs er\n (%.2f) " % egenkapital)

# %%
def investeringsprosjekt():
    investeringsbeløp = input('Hvor stort engangs investeringsbeløp?\n')
    investeringsbeløp = float(investeringsbeløp)
    
    rente = input('Hva er forventet avkastning i rente?\n')
    rente = float(rente)
    
    perioder = input('Hvor mange år skal pengene investert?\n')
    perioder = float(perioder) 
    
    fv = investeringsbeløp * (1 + rente/100)**perioder
    
    
    x_akse = np.linspace(0, perioder, int(fv))
    y_akse = investeringsbeløp * (1 + rente/100) ** x_akse
    fig = plt.figure(figsize=(10,5))
    plt.plot(x_akse, y_akse)
    plt.ylabel("Beløp")
    plt.xlabel("År")
    plt.ticklabel_format(useOffset=False, style='plain')
    
    plt.show()
    print("Ditt beløp vil være \n (%.2f) " % fv)

# %%
def serie():
    lanemengde = input('Hvor mye vil du låne? \n')
    lanemengde = float(lanemengde.replace(' ', ''))

    terminer = int(input('Hvor mange år vil du ha lånet? \n')) * 12

    rente = float(input('Hva er renten på lånet ditt? \n').replace(',', '.').replace('%', '')) / 100 / 12




    avdrag = lanemengde/terminer


    tabell = []

    termin = 1

#viktig for hver iturasjon, så legger vi til inn en rad. legger liste inn med alle kolonnene for den raden.

 
    for termin in range(1, terminer):
        m_rente = rente * lanemengde
        terminbelop = m_rente+avdrag 
        lanemengde = lanemengde - avdrag
        tabell.append([termin, terminbelop, m_rente, avdrag, lanemengde])
       

    inn = 1
 


    df = pd.DataFrame(tabell, columns=['Termin', 'Terminbeløp', 'Renter', 'Avdrag', 'Restgjeld']).astype(int)
    while (inn != 0 ):
        #Du har hele tabellen også tar den fra posisjon eks 0-4 (5 første pos) to_string er til bruk for å ikke vise index- da får du string, som du printer
        #truncate gjør at vi for bare 5 isteden for hele tabellen. 
        print(df.truncate(before=inn - 1, after=inn + 3).to_string(index=False))
        inn = int(input('\nHvilken termin vil du se? (0 for å avslutte)\n: '))

# %%
while True: 
    inn =input(f'\n1) Annunitetslån\n2) Serielån\n3) Kredittgjeld\n4) Egenandel på huslån\n5) Investeringsprosjekt\n\n0)Avslutt')
    if(inn=='1'):
        annunitets()
    elif(inn == '2'):
        serie()
    elif(inn == '3'):
        kredit()
    elif(inn=='4'):
        egenandel()
    elif(inn == '5'):
        investeringsprosjekt()
    elif(inn == '0'):
        break 
    else:
        print('Ugyldig')

# %% [markdown]
# # Semesteroppgave Python-lab 1003
# (av Erlend Kristensen Olsen, Jørgen Johansen og Morten André Ivarrud)
#
# I denne høstens semesteroppgave i Python-lab (SOK-1003) har vi hatt som mål å ferdigstille en kalkulator som kan hjelpe bruker med å regne ut ulike økonomiske problemstillinger (annuitetslån, serielån,…) på en brukervennlig måte, og samtidig framstille resultatene grafisk på en oversiktlig måte.
#
#  Vi valgte denne oppgaven fordi vi så en mulighet til å dekke store deler av pensum fra dette semesteret. Vi har måtte anvende det som vi har lært fra emnet Python-lab, men også hatt stor nytte av den økonomiske og matematiske teorien fra de andre fagene vi har vært gjennom i høst. Vi så på det som en fin og dekkende utfordring å lage en nyttig og brukervennlig kalkulator.
#
#  Inspirasjon til oppgaven har vi hentet blant annet fra de interaktive notatene i Jupyter (pensum), mattebøker, hjelpsomme nettsider som stackoverflow og datacamp, samt utallige google-søk. Kombinert har disse kildene hjulpet oss fremover i prosessen.
#
# Det finnes mange variasjoner av kalkulatorer på nettet. Vi er spesielt godt fornøyde med å ha implementert grafiske fremstillinger som gir brukeren et ekstra godt bilde av utregningen i ønsket periode. Pakker som Pandas, Numpy og Matplotlib har vært fundamentale i vårt arbeid. Disse har hjulpet oss å angripe de ulike problemstillingene vi har kommet over.
#
#  Når koden kjøres vil brukeren bli stilt en rekke med spørsmål, først angående hvilken av fem forskjellige typer kalkuleringer den ønsker utført (“serielån”, “annuitetslån”, “kredittgjeld”, “egenandel på huslån” og “investeringsprosjekt”). Deretter kommer spørsmål angående sum, renteverdi og tidslengde før utregningen til slutt returneres. På “serielån”, “annuitetslån” og “egenandel på huslån” følger det også  med  en grafisk fremstilling av resultatet.
#
#
#
# Måten vi har gått frem på er at vi har skrevet input-funksjoner for så å knytte disse sammen med enkle spørsmål ved hjelp av strings. Vi har definert disse variablene før vi har sydd dem sammen med matematiske formler.
#
# Vi har tatt i bruk matplotlib for å lage  grafer til de forskjellige lånene. Her brukte vi plt.xlabel/ylabel for å gi navn på x og y aksen, så brukt “ticklabel_format” kommandoen slik at resultatet kommer ut i heltall. Til slutt kommer “show” kommandoen som gjør at grafen kommer opp når koden kjøres.
#
# Vi har også laget en enkel egenandelskalkulator. Denne er standardisert slik at 15% av huslånets verdi blir egenkapital. Her har vi lagt til et pie-diagram ved hjelp av matplotlib for å gi brukeren et visuelt bilde på hvor mye av kaka du trenger i egenandel i henhold til lånet du tar opp.
#
# For å kunne se betalingsplanen på serielån og annuitetslån har vi brukt pandas. Vi brukte pd.DataFrame-funksjonen til å lage de ulike kolonnene med termin, terminbeløp, renter, avdrag, restgjeld. Etter å ha definert de ulike kolonnene bruker vi matematiske formler som gir riktig output i DataFrame. Vi brukte .append-kommandoen til å sortere rekkefølgen på kolonnene etter å ha definert dem. Vi har også brukt en kommando som sier while !=0:, det denne gjør er at så lenge tallet ikke er null, så vil koden kjøre. Truncate-kommandoen, hvor vi plotter inn “before = inn -1, after = inn + 3”, gjør det slik at det kun vises fem rekker om gangen. Fordi vi bruker pandas så blir blir det en index på siden av datasettet vi får opp. For å få vekk denne brukete vi kommandoen “index=False”. Når brukeren blir spurt om hvilken periode den ønsker å se kan hen plotte inn et tall og dermed få opp ønsket periode i tillegg til de fire påfølgende periodene.
# Etter å ha definert alle funksjonene i koden vår brukte vi en “while True loop” som sørger for at koden kjøres helt til vi utfører en break-kommando. Det er her vi har ulike inputs for de ulike kalkulatorerne hvor bruker får spørsmål om hvilke kalkulator de ønsker å disponere. Vi har brukt en “elif-kommando” som fungerer slik at hvis den forrige uttalelsene ikke var sann, så prøver den videre på de påfølgende helt til den treffer en som er sann. Hvis bruker ønsker å avslutte programmet så har vi lagt til en avslutt-kommando som heter “break”. Hvis bruker skriver inn et ugyldig input har vi brukt en else-kommando som fører til at det vil bli printet ut “Ugyldig”. Dette vil ikke avslutte loopen, men stille bruker samme spørsmål på nytt.
#
# Som konklusjon så ønsker vi å få frem at python er et brukervennlig språk som er lett å lese. Det er enkelt å tyde hva du vil frem til i koden. Det er utrolig mye hjelp å finne på nettet, og alt og ingenting er blitt kodet i python. Mange har samme spørsmål, så det er lett å kunne finne informasjon på nettet gjør det hele så mye mere brukervennlig. Det å samarbeide på gruppe sammen gjør at alle kan komme med ulike innspill og forslag for å forbedre koden. Det finnes utallige måter og metoder på hvordan man skal angripe et problem i python, så kan man sammenligne kodene og komme fram til den beste løsningen sammen på problemet.
#
#
#
#
#
#
#
# Kilder:
# Nordea() Egenkapital til boliglån.
# https://www.nordea.no/privat/vare-produkter/lan-og-kreditt/boliglan/egenkapital.html
#
# Usman, Malik(2020, 21.Oktober) Python Data Visualization with Matplotlib.
# https://stackabuse.com/python-data-visualization-with-matplotlib/
#
# NumPy v1.21 Manual.(u.å.) hentet 3.12.2021
# https://numpy.org/doc/stable/index.html
#
# Pandas.DataFrame(u.å) hentet 3.12.2021
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
#
# Jupyter notebooks SOK-1003
